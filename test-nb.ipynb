# %%
import numpy as np
import csv
from pathlib import Path
from os import remove
import json
import os

# %%
with open("../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/Monday-WH-generate-labeled.csv") as f:
    reader = csv.reader(f)
    labels = next(reader)
#     print(labels)
dstPort = labels[5]
print(dstPort)
# labels = [labels[7]] + [dstPort] + labels[8:-1]
labels = [dstPort] + labels[8:-1]
print(labels)
print(len(labels))
# Out:
# Dst Port
# ...

# %%
features_to_change = ["Tot Fwd Pkts", 
                      "Fwd Pkt Len Max", 
                      "Fwd Pkt Len Min",
                      "Pkt Len Min", 
                      "Pkt Len Max",
    
                      "Flow Duration", 
                      "Flow IAT Max", 
                      "Flow IAT Min", 
                      "Fwd IAT Max", 
                      "Fwd IAT Min", 
                      
                      "Fwd PSH Flags", 
                      "Fwd URG Flags",
                      "URG Flag Cnt",  
                      "FIN Flag Cnt",
                      "SYN Flag Cnt",
                      "RST Flag Cnt",
                      "PSH Flag Cnt",
                      "ACk Flag Cnt",
                      "ECE Flag Cnt",
                      "CWE Flag Count", 
                      
                      "Init Fwd Win Byts"]

features_for_flow_matching = ["Flow Duration", 
                              "Tot Fwd Pkts", 
                              "Tot Bwd Pkts", 
                              "TotLen Fwd Pkts", 
                              "Fwd Pkt Len Max", 
                              "Fwd Pkt Len Min", 
                              "Pkt Len Min", 
                              "Pkt Len Max",
                              "Fwd IAT Mean",
                              "Fwd IAT Std",
                              "Tot Fwd Pkts", 
                              "Fwd IAT Min",
                              
                              "Flow Duration", 
                              "Flow IAT Max", 
                              "Flow IAT Min", 
                              "Fwd IAT Max", 
                              "Fwd IAT Min", 
                              
                              # add feats to change
                              "Flow IAT Min",
                              "Fwd PSH Flags", 
                              "Fwd URG Flags",
                              "URG Flag Cnt",  
                              "FIN Flag Cnt",
                              "SYN Flag Cnt",
                              "RST Flag Cnt",
                              "PSH Flag Cnt",
                              "ACK Flag Cnt",
                              "ECE Flag Cnt",
                              "CWE Flag Count", 

                              "Init Fwd Win Byts"
                              
                              
                              
#                               "Fwd Pkt Len Max", 
#                               "Fwd Pkt Len Min",
#                               "Pkt Len Min", 
#                               "Pkt Len Max",

#                               "Flow Duration", 
#                               "Flow IAT Max", 
#                               "Flow IAT Min", 
#                               "Fwd IAT Max", 
#                               "Fwd IAT Min", 

#                               "Fwd PSH Flags", 
#                               "URG Flag Cnt",  
#                               "FIN Flag Cnt", 
#                               # more flags here!!!!
#                               "CWE Flag Count", 

#                               "Init Fwd Win Byts"
                             ] # help us match which feature flow goes to which flow extracted from pcap

# %%
for f in features_to_change:
    print(f in labels)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True

# %%
attack_str = "PAE_rslt_adv_features/PAE_plus"
# attack_str = "BiGAN_adv_features/Bi"
# attack = "Bot"
NID = "PAE_plus"

# # FTP-Patator
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsFTP-Patator.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_FTP-Patator.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_FTP-Patator.npy")
# attack = "FTP_Patator"
# day = "Tuesday"

# #SSH-Patator
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsSSH-Patator.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_SSH-Patator.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_SSH-Patator.npy")
# attack = "SSH_Patator"
# day = "Tuesday"

# # DoS_GoldenEye
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsDoS_GoldenEye.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_DoS_GoldenEye.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_DoS_GoldenEye.npy")
# attack = "DoS_GoldenEye"
# day = "Wednesday"

# # Dos_Hulk
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsDoS_Hulk.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_DoS_Hulk.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_DoS_Hulk.npy")
# attack = "DoS_Hulk"
# day = "Wednesday"

# # Dos SlowHttptest
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsDoS_Slowhttptest.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_DoS_Slowhttptest.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_DoS_Slowhttptest.npy")
# attack = "DoS_Slowhttptest"
# day = "Wednesday"

# # DoS_Slowloris
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsDoS_Slowloris.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_DoS_Slowloris.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_DoS_Slowloris.npy")
# attack = "DoS_Slowloris"
# day = "Wednesday"

# # # Heartbleed
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsHeartbleed.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_Heartbleed.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_Heartbleed.npy")
# attack = "Heartbleed"
# day = "Wednesday"

# # # Infiltration
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsInfiltration.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_Infiltration.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_Infiltration.npy")
# attack = "Infiltration"
# day = "Thursday"

# # # # Web_Attack_BruteForce
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsWeb_Attack_BruteForce.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_Web_Attack_BruteForce.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_Web_Attack_BruteForce.npy")
# attack = "Web_Attack_BruteForce"
# day = "Thursday"

# # Web_Attack_SqlInjection
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsWeb_Attack_SqlInjection.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_Web_Attack_SqlInjection.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_Web_Attack_SqlInjection.npy")
# attack = "Web_Attack_SqlInjection"
# day = "Thursday"

# # Web_Attack_XSS
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsWeb_Attack_XSS.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_Web_Attack_XSS.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_Web_Attack_XSS.npy")
# attack = "Web_Attack_XSS"
# day = "Thursday"

# # BOT
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsBot.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_Bot.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_Bot.npy")
# attack = "Bot"
# day = "Friday"

# # PORT SCAN
# bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsPortScan.npy")
# bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_PortScan.npy")
# bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_PortScan.npy")
# attack = "PortScan"
# day = "Friday"

# DDoS
bot_ids = np.load("../NetSploit-files/adv_flow_based_features/flow_IDs/flow_idsDDoS.npy")
bot_bi_adv_feat = np.load("../NetSploit-files/adv_flow_based_features/" + attack_str + "_adv_features_DDoS.npy")
bot_og_feat = np.load("../NetSploit-files/adv_flow_based_features/orig_features/orig_features_DDoS.npy")
attack = "DDoS"
day = "Friday"

# %%
og_csv_feat_file = "../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/" + day + "-WH-generate-labeled.csv"
og_timeout_counts = {}
og_adv_timeout_count = {}
with open(og_csv_feat_file, "r") as og_f:
    og_f = csv.reader(og_f)
    next(og_f)
    for row in og_f:
        if row[1] not in og_timeout_counts:
            og_timeout_counts[row[1]] = 0
        else:
            og_timeout_counts[row[1]] += 1
        
        label_index = len(row) - 1
        attack_count = 0
        if row[label_index] == attack:
            if row[1] not in og_adv_timeout_count:
                og_adv_timeout_count[row[1]] = []
            og_adv_timeout_count[row[1]].append(og_timeout_counts[row[1]])
            attack_count += 1
            if attack_count == 5000:
                break
#         print(row[1])

print(len(og_adv_timeout_count))
# print(og_adv_timeout_count)
# Out:
# 45392

# %%
feature_json = "../NetSploit-files/json_files/" + "feature_set_" + attack# + ".json"
flows_to_extract = 'flows-and-features-to-extract.txt'
out_pcap = Path(flows_to_extract)
if out_pcap.is_file():
    os.remove(flows_to_extract)
    
total_feat_vecs = 0
flow_num = 0
vectors_to_extract = []
feature_set = {
    "flows": {}
}

timeout_counts = {}
limit_hit = 0
total = 0

config_map = {}
for ids, adv, og in zip(bot_ids, bot_bi_adv_feat, bot_og_feat):
    feature_json = "../NetSploit-files/json_files/" + "feature_set_" + attack
    timestamp = None
    flag = True
    label_ind = 0
    num_diff_flows = 0
    dump_last = True


#     print(ids[0])
    proto = str(ids[5])
    srcIP = str(ids[1])
    srcPort = str(ids[2])
    dstIP = str(ids[3]) 
    dstPort = str(ids[4])
    config = proto + "," + srcIP + "," + srcPort + "," + dstIP + "," + dstPort
    if config in config_map:
        config_map[config] += 1
#         print("config, timeout: ({}, {})".format(config, config_map[config]))
    elif ids[0] in og_adv_timeout_count:
        config_map[config] = og_adv_timeout_count[ids[0]][0]
    else:
        config_map[config] = 0
    
    for i in range(len(adv)):
        if adv[i] != og[i] and labels[label_ind] in features_to_change or not flag and labels[label_ind] in features_for_flow_matching:
            if flag:
#                 config += "," + 

                if config not in feature_set["flows"]:
                    feature_set["flows"][config] = {}
                feature_set["flows"][config][str(config_map[config])] = {}

                    

#                 print(config_map[config])
#                 print(feature_set["flows"][config])
#                 config += "," + str(config_map[config])
#                 if config_map[config] == 0:
#                     feature_set["flows"][config] = {}
#                     feature_set["flows"][config][str(config_map[config])] = {}
                    
# #                 feature_set["flows"][config]["timestamp"] = timestamp
#                 feature_set["flows"][config][str(config_map[config])] = {}
                feature_set["flows"][config][str(config_map[config])]["features"] = {}
                
                vectors_to_extract.append(flow_num)
#                 print("flow_num: {}".format(flow_num))
                flag = False
                
#             print("flow num no flag: {}".format(flow_num))
            feature_set["flows"][config][str(config_map[config])]["features"][labels[label_ind]] = {}
            feature_set["flows"][config][str(config_map[config])]["features"][labels[label_ind]]["og"] = og[i]
            feature_set["flows"][config][str(config_map[config])]["features"][labels[label_ind]]["adv"] = adv[i]

        label_ind += 1
    flow_num += 1
#     if len(vectors_to_extract) == 100000:
#         feature_json += "_" + str(limit_hit) + ".json" # + "_" + str(len(vectors_to_extract)) + ".json"
#         limit_hit += 1
#         with open(feature_json, 'w') as f:  # writing JSON object
#             json.dump(feature_set, f)
#         feature_set = { "flows": {} }
#         print(vectors_to_extract)
#         total += len(vectors_to_extract)
#         vectors_to_extract = []
#         dump_last = False

if dump_last:
    total += len(vectors_to_extract)
#     print(vectors_to_extract)
    feature_json += "_" + NID + "_TO.json"
#     feature_json += "_" + str(limit_hit) + ".json" #"_" + str(len(vectors_to_extract)) + ".json"

    with open(feature_json, 'w') as f:  # writing JSON object
        json.dump(feature_set, f)
#     print(feature_set)

print("vectors to extract: {}".format(total))

feats_written = 0
for k,v in feature_set["flows"].items():
    for timeout,feature in v.items():
        feats_written += 1

print("written: {}".format(feats_written))
print("extracted: {}".format(total))
# print(config_map)
# print(vectors_to_extract)
# print("vectors to extract: {}".format(len(vectors_to_extract)))
# print(feature_set)
# Out:
# vectors to extract: 163
# written: 163
# extracted: 163

# %%
# START: Create adversarial feature files!
# 1) GET Json files and adv feature file names
# 
# attack = "Bot"
# attacks = ["Bot", "DDoS", "PortScan"]
attacks = ["BruteForce", "XSS", "Infiltration"] #"SqlInjection", 
# attacks = ["GoldenEye", "Hulk", "Slowhttptest", "Slowloris"]
# attacks = ["FTP-Patator", "SSH-Patator"]
day = "Thursday"
NID = "PAE_rslt"
# adv_csv_name = "Friday-WH-without-Bot.csv"
# feature_json = "../NetSploit-files/json_files/" + NID + "/all_in_one/feature_set_" + attack + "_all_in_one.json"
og_csv_feat_file = "../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/" + day + "-WH-generate-labeled.csv"
# new_csv_file = "../NetSploit-files/pcaps/BiGAN/Modded/" + attack + "/" + attack + "_" + day + "_modded.pcap_Flow.csv"
writeback_csv = "../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/" + day + "-WH-" + NID + "-without"

adv_jsons = []
adv_features = []
for attack in attacks:
    if day == "Thursday" and attack != "Infiltration":
        j_attack = "Web_Attack_" + attack
    elif day == "Wednesday":
        j_attack = "DoS_" + attack
    elif attack == "FTP-Patator":
        j_attack = "FTP_Patator"
    elif attack == "SSH-Patator":
        j_attack = "SSH_Patator"
    else:
        j_attack = attack
    writeback_csv += "-" + attack
    if NID == "PAE_rslt":
        adv_json = "../NetSploit-files/json_files/" + NID + "/all_in_one/feature_set_" + j_attack + "_" + "PAE_plus_TO.json"
        adv_feature = "../NetSploit-files/pcaps/" + NID + "/" + attack + "/" + attack + "_" + day + "_PAE_rslt_modded.pcap_Flow.csv"
    else:
        adv_json = "../NetSploit-files/json_files/" + NID + "/all_in_one/feature_set_" + j_attack + "_" + NID + "_TO.json"
        adv_feature = "../NetSploit-files/pcaps/" + NID + "/" + attack + "/" + attack + "_" + day + "_modded.pcap_Flow.csv"
    adv_jsons.append(adv_json)
    adv_features.append(adv_feature)
writeback_csv += ".csv"
print(adv_jsons)
print(adv_features)
print(writeback_csv)
# Out:
# ['../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Web_Attack_BruteForce_PAE_plus_TO.json', '../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Web_Attack_XSS_PAE_plus_TO.json', '../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Infiltration_PAE_plus_TO.json']
# ['../NetSploit-files/pcaps/PAE_rslt/BruteForce/BruteForce_Thursday_PAE_rslt_modded.pcap_Flow.csv', '../NetSploit-files/pcaps/PAE_rslt/XSS/XSS_Thursday_PAE_rslt_modded.pcap_Flow.csv', '../NetSploit-files/pcaps/PAE_rslt/Infiltration/Infiltration_Thursday_PAE_rslt_modded.pcap_Flow.csv']
# ../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/Thursday-WH-PAE_rslt-without-BruteForce-XSS-Infiltration.csv

# %%
# get indices in the original CSV file (no adv), that need to be removed because we created adv exampels for them
out_pcap = Path(writeback_csv)
if out_pcap.is_file():
    os.remove(writeback_csv)

adv_match_indices = []
adv_match_flows = []
adv_flow_durs = []
labels_of_indices_to_remove = []
flow_keys = []
benign_count_list = []

print(og_csv_feat_file)

with open(og_csv_feat_file) as of:    
    og_f = csv.reader(of, delimiter=',')
    for i in range(len(adv_features)):
        of.seek(0)
#         og_f = csv.reader(og_f, delimiter=',')
        with open(adv_features[i], "r") as af:
            print(adv_features[i])
            print(adv_jsons[i])
            adv_f = csv.reader(af, delimiter=',')
            with open(adv_jsons[i], "r") as j:
                config = json.load(j)
                config = config["flows"]
                count = 0
                for k,v in config.items():
                    for timeout, feature in v.items():
                        count += 1
                        duration = feature["features"]["Flow Duration"]["og"]
                        adv_flow_durs.append(int(duration))
#                 print(len(adv_flow_durs))
#                 print("count: {}".format(count))
            
            adv_keys = []
            adv_count = 0
            for ak in adv_f:
                if adv_count != 0:
                    adv_keys.append(ak[0])
                adv_count += 1
#             print(adv_keys)
#             print("adv_count: {}".format(adv_count))
            
            og_count = 0
            adv_match = 0
            benign_count = 0
            for ok in og_f:
                if ok[1] in adv_keys:# and int(ok[8]) in adv_flow_durs:
#                     print(ok[len(ok) - 1])
#                     print(ok)
                    label = ok[len(ok) - 1]
                    duration = ok[8]
                    fwd_pkts = ok[9]
                    bwd_pkts = ok[10]
                    adv_match += 1
#                     fwdpktlen_max = ok[13]
#                     fwdpktlen_min = ok[14]
                    flow_id = ((ok[1], duration, fwd_pkts, bwd_pkts), (label))
#                     flow_id = ((ok[1], fwd_pkts, bwd_pkts), (label))
                    adv_match_indices.append(flow_id)
                    print(flow_id)
                    if label == "BENIGN":
                        benign_count += 1
#                     labels_of_indices_to_remove.append(ok[len(ok) - 1])
                    adv_match_flows.append(ok[1])
                og_count += 1
#             print("new indices to remove: {}".format(adv_match))
            print("current loop adv indices length: {}".format(adv_match))
        benign_count_list.append(benign_count)

print("benign_counts: {}".format(benign_count_list))
print("len adv_match flow: {}".format(len(adv_match_flows)))
# print("END indices to remove: {}".format(adv_match_indices))
# print("Total # of indices to remove: {}".format(len(adv_match_indices)))
# print("adv_match_indices: {}".format(adv_match_indices))

# k = k.split(',')
# flow = ""
# if k[1] < k[3]:
#     flow += k[1] + "-" + k[3] + "-"
# else:
#     flow += k[3] + "-" + k[1] + "-" 

# if "8080" in k:
#     if k[2] == "8080":
#         flow += k[4] + "-" + k[2] + "-"
#     else:
#         flow += k[2] + "-" + k[4] + "-"
# else:
#     if k[2] < k[4]:
#         flow += k[4] + "-" + k[2] + "-"
#     else:
#         flow += k[2] + "-" + k[4] + "-"
# flow += k[0]
# flow_keys.append(flow)
# Out:
# ../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/Thursday-WH-generate-labeled.csv
# ../NetSploit-files/pcaps/PAE_rslt/BruteForce/BruteForce_Thursday_PAE_rslt_modded.pcap_Flow.csv
# ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Web_Attack_BruteForce_PAE_plus_TO.json
# (('172.16.0.1-192.168.10.50-44634-80-6', '20847788', '83', '43'), 'Web Attack - Brute Force')
# (('172.16.0.1-192.168.10.50-44634-80-6', '470', '1', '1'), 'BENIGN')
# current loop adv indices length: 2
# ../NetSploit-files/pcaps/PAE_rslt/XSS/XSS_Thursday_PAE_rslt_modded.pcap_Flow.csv
# ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Web_Attack_XSS_PAE_plus_TO.json
# (('172.16.0.1-192.168.10.50-32906-80-6', '355', '2', '0'), 'Web Attack - XSS')
# (('172.16.0.1-192.168.10.50-32906-80-6', '68337890', '203', '104'), 'Web Attack - XSS')
# (('172.16.0.1-192.168.10.50-33580-80-6', '315', '2', '0'), 'Web Attack - XSS')
# ...

# %%
# Create PCAP w/o adv_feature flows
print("reading from: {}".format(og_csv_feat_file))
print("writing to: {}".format(writeback_csv))
with open(og_csv_feat_file, 'r') as og_f:
    og_reader = csv.reader(og_f)
    with open(writeback_csv, "w") as wb:
        print(og_f)
        writer = csv.writer(wb, delimiter=',')
        index = 0
        counter = 0
        for og_row in og_reader:
            if og_row[1] in adv_match_flows:
                counter += 1
                print(index, og_row[1])
            else:
                writer.writerow(og_row)
            index += 1
print(counter)
# Out:
# reading from: ../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/Thursday-WH-generate-labeled.csv
# writing to: ../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/Thursday-WH-PAE_rslt-without-BruteForce-XSS-Infiltration.csv
# <_io.TextIOWrapper name='../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/Thursday-WH-generate-labeled.csv' mode='r' encoding='UTF-8'>
# 23507 172.16.0.1-192.168.10.50-32906-80-6
# 23508 172.16.0.1-192.168.10.50-32906-80-6
# 23631 172.16.0.1-192.168.10.50-33580-80-6
# 23632 172.16.0.1-192.168.10.50-33580-80-6
# 23763 172.16.0.1-192.168.10.50-34278-80-6
# 23764 172.16.0.1-192.168.10.50-34278-80-6
# 23887 172.16.0.1-192.168.10.50-34940-80-6
# 23888 172.16.0.1-192.168.10.50-34940-80-6
# 23889 172.16.0.1-192.168.10.50-34940-80-6
# 23890 172.16.0.1-192.168.10.50-34940-80-6
# 24827 172.16.0.1-192.168.10.50-44634-80-6
# 24828 172.16.0.1-192.168.10.50-44634-80-6
# 26124 172.16.0.1-192.168.10.50-52298-80-6
# 26125 172.16.0.1-192.168.10.50-52298-80-6
# ...

# %%
# Label and remove header row of adversarial feature files
adv_files_to_merge = []

i = 0
adv_flow_durs = []
check_max_iat = []
match_count = 0
for attack_file in adv_features:
    attack = attack_file.split("/")
    attack = attack[4]
    print(attack)
    with open(adv_jsons[i], "r") as j:
        print("adv json: {}".format(adv_jsons[i]))
        config = json.load(j)
        config = config["flows"]
        count = 0
        for k,v in config.items():
            for timeout, feature in v.items():
                count += 1
                duration = feature["features"]["Flow Duration"]["adv"]
                adv_flow_durs.append(int(duration))
#                 duration = feature["features"]["Flow Duration"]["og"]
#                 adv_flow_durs.append(int(duration))
#                 check_max_iat.append(feature["features"]["Fwd IAT Max"]["adv"] * 1.1)
#         print(adv_flow_durs)
#         print(check_max_iat)
#         print(type(adv_flow_durs[0]))
    #                 print(len(adv_flow_durs))
    with open(attack_file) as afc:
        af = csv.reader(afc)
        next(af)
        label_and_pruned_af = attack_file[:-20] + "pruned_labeled.csv"
        out_pcap = Path(label_and_pruned_af)
        if out_pcap.is_file():
            os.remove(label_and_pruned_af)
        adv_files_to_merge.append(label_and_pruned_af)
#         print(label_and_pruned_af)
        with open(label_and_pruned_af, "w") as lf:
            lpf = csv.writer(lf, delimiter=',')
            for row in af:
                key = row[0]
                duration = row[7]
                fwd_pkts = row[8]
                bwd_pkts = row[9]
#                 fwdpktlen_max = row[12]
#                 fwdpktlen_min = row[13]
                if day == "Thursday":
                    if attack != "Infiltration":
                        if attack == "BruteForce":
                            name = "Brute Force"
                        else:
                            name = attack
                        label = "Web Attack - " + name
                    else:
                        label = attack
                if day == "Wednesday":
                    if attack == "GoldenEye":
                        label = "DoS GoldenEye"
                    elif attack == "Slowloris":
                        label = "DoS slowloris"
                    elif attack == "Slowhttptest":
                        label = "DoS Slowhttptest"
                    elif attack == "Hulk":
                        label = "Dos Hulk"
                else:
                    label = attack
                
#                 check = (key, fwd_pkts, bwd_pkts)
                check = (key, duration, fwd_pkts, bwd_pkts)
#                 print("looking for: {}".format(check))
                label_index = len(row) - 1
                for val in adv_match_indices:
#                     print(check,val[0])
                    if check == val[0]:
#                         print("found: {}".format(val))
                        row[label_index] = val[1]
#                 print(row[label_index])
                if row[label_index] == "No Label":
                    print("no label: {},{}".format(row[0], row[7]))
                    row[label_index] = label
#                     print("label! {}".format())
                lpf.writerow(row)
#             afc.seek(0)
#             lf.seek(0)
# #             next(af)
#             for row in af:
#                 if row[len(row) - 1] == "No Label":
#                     row[len(row) - 1] = label
#                 lpf.writerow(row)
        
#                 print(row[7])
#                 if int(row[7]) in adv_flow_durs or int(row[7]) in check_max_iat:
#                     match_count += 1
#                     print("match attack: {}".format(attack))
#                 label_index = len(row) - 1
#                 row[label_index] = attack
#                 lpf.writerow(row)
    i += 1

print("files pruned and merged: {}".format(adv_files_to_merge))
print("match_count: {}".format(match_count))
# Out:
# BruteForce
# adv json: ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Web_Attack_BruteForce_PAE_plus_TO.json
# no label: 172.16.0.1-192.168.10.50-44634-80-6,20864596
# XSS
# adv json: ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_Web_Attack_XSS_PAE_plus_TO.json
# no label: 172.16.0.1-192.168.10.50-52298-80-6,612914
# no label: 172.16.0.1-192.168.10.50-52910-80-6,62560268
# no label: 172.16.0.1-192.168.10.50-52910-80-6,681653
# no label: 172.16.0.1-192.168.10.50-53584-80-6,624119
# no label: 172.16.0.1-192.168.10.50-54268-80-6,60429908
# no label: 172.16.0.1-192.168.10.50-54268-80-6,748581
# no label: 172.16.0.1-192.168.10.50-54956-80-6,606877
# no label: 172.16.0.1-192.168.10.50-55632-80-6,67650808
# no label: 172.16.0.1-192.168.10.50-55632-80-6,705939
# no label: 172.16.0.1-192.168.10.50-56306-80-6,1060659
# no label: 172.16.0.1-192.168.10.50-56994-80-6,66909280
# no label: 172.16.0.1-192.168.10.50-56994-80-6,882967
# ...

# %%
# Merge attack files and original feature file (minus attack flows) together
combined_csv = "../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/" + day + "-" + NID + "-done.csv"
# writeback_csv = "../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/Friday-WH-without-Bot-DDoS-PortScan.csv"
# attacks = ["Bot", "DDoS", "PortScan"]
# day = "Friday"

with open(combined_csv, "w") as cc:
    cc_writer = csv.writer(cc, delimiter=',')
    with open(writeback_csv, "r") as wb:
        wb_reader = csv.reader(wb)
        for wb_row in wb_reader:
            wb_row = wb_row[1:]
            last_index = len(wb_row) - 1
            if wb_row[last_index] == "" or "Label" in wb_row[last_index]:
                wb_row[last_index] = "BENIGN"
            cc_writer.writerow(wb_row)
    #write adv_feat files to csv
    for att_file in adv_files_to_merge: 
        with open(att_file, "r") as f:
            f = csv.reader(f)
            for row in f:
                cc_writer.writerow(row)
# END!

# %%
# START: Create adversarial feature files!
# 1) GET Json files and adv feature file names
# 
# attack = "Bot"
# attacks = ["Bot", "DDoS", "PortScan"]
# attacks = ["BruteForce", "XSS", "Infiltration"] #"SqlInjection", 
attacks = ["GoldenEye", "Hulk", "Slowhttptest", "Slowloris"]
# attacks = ["FTP-Patator", "SSH-Patator"]
day = "Wednesday"
NID = "PAE_rslt"
# adv_csv_name = "Friday-WH-without-Bot.csv"
# feature_json = "../NetSploit-files/json_files/" + NID + "/all_in_one/feature_set_" + attack + "_all_in_one.json"
og_csv_feat_file = "../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/" + day + "-WH-generate-labeled.csv"
# new_csv_file = "../NetSploit-files/pcaps/BiGAN/Modded/" + attack + "/" + attack + "_" + day + "_modded.pcap_Flow.csv"
writeback_csv = "../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/" + day + "-WH-" + NID + "-without"

adv_jsons = []
adv_features = []
for attack in attacks:
    if day == "Thursday" and attack != "Infiltration":
        j_attack = "Web_Attack_" + attack
    elif day == "Wednesday":
        j_attack = "DoS_" + attack
    elif attack == "FTP-Patator":
        j_attack = "FTP_Patator"
    elif attack == "SSH-Patator":
        j_attack = "SSH_Patator"
    else:
        j_attack = attack
    writeback_csv += "-" + attack
    if NID == "PAE_rslt":
        adv_json = "../NetSploit-files/json_files/" + NID + "/all_in_one/feature_set_" + j_attack + "_" + "PAE_plus_TO.json"
        adv_feature = "../NetSploit-files/pcaps/" + NID + "/" + attack + "/" + attack + "_" + day + "_PAE_rslt_modded.pcap_Flow.csv"
    else:
        adv_json = "../NetSploit-files/json_files/" + NID + "/all_in_one/feature_set_" + j_attack + "_" + NID + "_TO.json"
        adv_feature = "../NetSploit-files/pcaps/" + NID + "/" + attack + "/" + attack + "_" + day + "_modded.pcap_Flow.csv"
    adv_jsons.append(adv_json)
    adv_features.append(adv_feature)
writeback_csv += ".csv"
# print(adv_jsons)
# print(adv_features)
# print(writeback_csv)

count = 0
counts = []
for adv_j in adv_jsons:
    with open(adv_j, "r") as j:
        print(adv_j)
        config = json.load(j)
        config = config["flows"]
        count = 0
        for k,v in config.items():
            for timeout, feature in v.items():
                count += 1
    counts.append(count)
print(counts)
# Out:
# ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_DoS_GoldenEye_PAE_plus_TO.json
# ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_DoS_Hulk_PAE_plus_TO.json
# ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_DoS_Slowhttptest_PAE_plus_TO.json
# ../NetSploit-files/json_files/PAE_rslt/all_in_one/feature_set_DoS_Slowloris_PAE_plus_TO.json
# [1122, 1432, 835, 884]

# %%
attack
# Out:
# 'Infiltration_Thursday_modded.pcap_Flow.csv'

# %%
# Label and remove header row of adversarial feature files
adv_files_to_merge = []

for attack_file in adv_features:
    attack = attack_file.split("/")
    attack = attack[4]
    print(attack)
    with open(attack_file) as af:
        af = csv.reader(af)
        next(af)
        label_and_pruned_af = attack_file[:-20] + "pruned_labeled.csv"
        adv_files_to_merge.append(label_and_pruned_af)
        print(label_and_pruned_af)
        with open(label_and_pruned_af, "w") as lpf:
            lpf = csv.writer(lpf, delimiter=',')
            for row in af:
                label_index = len(row) - 1
                row[label_index] = attack
                lpf.writerow(row)

print("files pruned and merged: {}".format(adv_files_to_merge))

# %%
import os, glob
import pandas as pd
attack = "PortScan"
day = "Friday"
NID = "BiGAN"
new_csv_file = "../NetSploit-files/pcaps/BiGAN/Modded/" + attack + "/" + attack + "_" + day + "_modded.pcap_Flow.csv"
to_write = new_csv_file[:-13] + "csv"

print(to_write)

# with open(new_csv_file,'r') as f:
#     with open(to_write,'w') as f1:
#         next(f) # skip header line
#         for line in f:
#             f1.write(line)

# with open(new_csv_file) as read_f:
#     read_reader = csv.reader(read_f)
#     index = 0
# Out:
# ../NetSploit-files/pcaps/BiGAN/Modded/PortScan/PortScan_Friday_modded.csv

# %%
# og_csv_feat_file = writeback_csv
# writeback_csv = writeback_csv[:-4] + "-" + attack + ".csv"


out_pcap = Path(writeback_csv)
if out_pcap.is_file():
    os.remove(writeback_csv)

adv_match_indeces = []
adv_match_flows = []

with open(og_csv_feat_file) as og_f:
    with open(new_csv_file) as adv_f:
        adv_flows_key = []
        adv_flows_dur = []
        with open(feature_json, 'r') as j:  # reading JSON object
            config = json.load(j)
            config = config["flows"]
            for k,v in config.items():
                duration = v["features"]["Flow Duration"]["og"]
#                 k = k.split(',')
#                 flow = ""
#                 if k[1] < k[3]:
#                     flow += k[1] + "-" + k[3] + "-"
#                 else:
#                     flow += k[3] + "-" + k[1] + "-" 
                
#                 if "8080" in k:
#                     if k[2] == "8080":
#                         flow += k[4] + "-" + k[2] + "-"
#                     else:
#                         flow += k[2] + "-" + k[4] + "-"
#                 else:
#                     if k[2] < k[4]:
#                         flow += k[4] + "-" + k[2] + "-"
#                     else:
#                         flow += k[2] + "-" + k[4] + "-"
#                 flow += k[0]
                adv_flows_dur.append(int(duration))

        og_f = csv.reader(og_f, delimiter=',')
        adv_f = csv.reader(adv_f, delimiter=',')
        adv_keys = []
        adv_count = 0
        for ak in adv_f:
            if adv_count != 0:
                adv_keys.append(ak[0])
            adv_count += 1
#         print(adv_keys)

        og_count = 0
        adv_match = 0
        for ok in og_f:
            if ok[1] in adv_keys and int(ok[8]) in adv_flows_dur: 
#                 print(ok[1], int(ok[8]))
                adv_match += 1
                adv_match_indeces.append(og_count)
                adv_match_flows.append((ok[1], ok[8]))
            og_count += 1
        print(adv_match)
        print(adv_match_indeces)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-135-86b30e48e066> in <module>()
#      18 adv_match_flows = []
#      19
# ---> 20 with open(og_csv_feat_file) as og_f:
#      21     with open(new_csv_file) as adv_f:
#      22         adv_flows_key = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '../NetSploit-files/CIC-Feature-Files/csv-adv-feature-files/Friday-WH-without.csv'

# %%
# print(bot_bi_adv_feat[0][0])
flows_to_extract = 'flows-to-extract.txt'
out_pcap = Path(flows_to_extract)
if out_pcap.is_file():
    os.remove(flows_to_extract)
    
print("need to extract the following {} vectors".format(len(vectors_to_extract)))
vector_counter = 0
for ids, vec in zip(bot_ids, bot_og_feat):
    if vector_counter not in vectors_to_extract:
        vector_counter += 1
        continue
#     print(ids,vec[0]) # dst ports
#     print(type(ids[0]))
#     ids = ids[0].split('-')
#     print(ids)
    proto = str(ids[5])
    srcIP = str(ids[1])
    srcPort = str(ids[2])
    dstIP = str(ids[3]) 
    dstPort = str(ids[4])
    
#     print(str(int(vec[0])))
#     dstPort_ind = ids.index(str(int(vec[0]))) # this gives index of dstPort
# #     print(dstPort_ind)
#     if dstPort_ind == 2:
#         dstPort = ids[2]
#         srcPort = ids[3]
#     else:
#         dstPort = ids[3]
#         srcPort = ids[2]
    config = proto + "," + srcIP + "," + srcPort + "," + dstIP + "," + dstPort
    print("index, config: {} -- {}".format(vector_counter, config))
    vector_counter += 1

    
    with open(flows_to_extract, 'a') as f:
        f.write(config + "\n")
        f.write()
# Out:
# need to extract the following 0 vectors

# %%
with open(flows_to_extract) as f:
    for flow in f:
        flow = flow[:-1].split(',')
        print(flow)
# Out:
# ['6', '192.168.10.14', '59054', '204.79.197.200', '443']
# ['6', '192.168.10.14', '49601', '204.8.234.202', '80']
# ['6', '192.168.10.14', '49641', '204.8.234.202', '80']
# ['6', '192.168.10.14', '49662', '204.8.234.202', '80']
# ['6', '192.168.10.14', '49827', '204.8.234.202', '80']
# ['6', '192.168.10.14', '49841', '204.8.234.202', '80']
# ['6', '192.168.10.14', '50016', '204.8.234.202', '80']
# ['6', '192.168.10.14', '50030', '204.8.234.202', '80']
# ['6', '192.168.10.14', '50140', '204.8.234.202', '80']
# ['6', '192.168.10.14', '50153', '204.8.234.202', '80']
# ['6', '192.168.10.14', '50183', '204.8.234.202', '80']
# ['6', '192.168.10.15', '56933', '204.236.236.52', '443']
# ['6', '192.168.10.15', '60043', '204.236.236.52', '443']
# ['6', '192.168.10.15', '50696', '204.79.197.200', '443']
# ['6', '192.168.10.15', '53761', '204.79.197.200', '443']
# ['6', '192.168.10.15', '56357', '204.79.197.200', '443']
# ['6', '192.168.10.15', '56358', '204.79.197.200', '443']
# ...

# %%
flow_num = 0
vectors_to_extract = []
for adv, og in zip(bot_bi_adv_feat, bot_og_feat):
    flag = True
    label_ind = 0
    num_diff_flows = 0
    for i in range(len(adv)):
#         print(len(adv))
#         print(adv[i], og[i])
        if adv[i] != og[i] and labels[label_ind] in features_to_change:
            print(flow_num, labels[label_ind], og[i], adv[i])
            if flag:
                vectors_to_extract.append(flow_num)
                flag = False
        label_ind += 1
    flow_num += 1
#     print(adv,og)
print(vectors_to_extract)
print(len(vectors_to_extract))
# Out:
# 5 Flow Duration 66581361.0 43548876.0
# 5 Tot Fwd Pkts 14.0 80.0
# 5 Flow IAT Max 10000937.0 10155875.0
# 5 Fwd IAT Max 10023371.0 17630604.0
# 5 Init Fwd Win Byts 8192.0 18161.0
# 8 Flow Duration 5314915.0 14267800.0
# 8 Tot Fwd Pkts 35.0 240.0
# 8 Flow IAT Max 3277631.0 5705371.0
# 8 Flow IAT Min 2.0 0.0
# 8 Fwd IAT Max 3277631.0 6086493.0
# 8 Init Fwd Win Byts 8192.0 2261.0
# 12 Flow Duration 4969555.0 10810292.0
# 12 Tot Fwd Pkts 36.0 211.0
# 12 Flow IAT Max 3000304.0 5975252.0
# 12 Fwd IAT Max 3000304.0 5715573.0
# 12 Init Fwd Win Byts 8192.0 3847.0
# 14 Flow Duration 5236706.0 7909119.0
# 14 Tot Fwd Pkts 34.0 155.0
# 14 Flow IAT Max 3243062.0 6707346.0
# 14 Flow IAT Min 6.0 0.0
# 14 Fwd IAT Max 3243147.0 6846974.0
# 14 Init Fwd Win Byts 8192.0 3303.0
# 18 Flow Duration 5240279.0 6003317.0
# 18 Tot Fwd Pkts 37.0 192.0
# 18 Flow IAT Max 3428011.0 6482025.0
# 18 Fwd IAT Max 3428011.0 7015180.0
# 18 Init Fwd Win Byts 8192.0 2964.0
# 20 Flow Duration 5264984.0 11408520.0
# ...

# %%
#print(bot_ids)
print(bot_ids[0])
print(len(bot_bi_adv_feat))
print(len(bot_og_feat))
# Out:
# ['192.168.10.12-52.51.222.188-43130-80-6' '192.168.10.12' 43130
#  '52.51.222.188' 80 6 '07/07/2017 12:42:09 PM']
# 1956
# 1956

# %%
# print(len(bot_bi_adv_feat[2]))
print(bot_og_feat[5][2], bot_og_feat[5][3])
print(bot_bi_adv_feat[5][2], bot_bi_adv_feat[5][3])
# Out:
# 14.0 22.0
# 80.0 22.0

# %%
flow_num
# Out:
# 1956

# %%
# get indices in the original CSV file (no adv), that need to be removed because we created adv exampels for them
out_pcap = Path(writeback_csv)
if out_pcap.is_file():
    os.remove(writeback_csv)

adv_match_indices = []
adv_match_flows = []
adv_flow_durs = []
labels_of_indices_to_remove = []

print(og_csv_feat_file)

with open(og_csv_feat_file) as of:    
    og_f = csv.reader(of, delimiter=',')
    for i in range(len(adv_features)):
        of.seek(0)
#         og_f = csv.reader(og_f, delimiter=',')
        with open(adv_features[i], "r") as af:
            print(adv_features[i])
            print(adv_jsons[i])
            adv_f = csv.reader(af, delimiter=',')
            with open(adv_jsons[i], "r") as j:
                config = json.load(j)
                config = config["flows"]
                count = 0
                for k,v in config.items():
                    for timeout, feature in v.items():
                        count += 1
                        duration = feature["features"]["Flow Duration"]["og"]
                        adv_flow_durs.append(int(duration))
#                 print(len(adv_flow_durs))
#                 print("count: {}".format(count))
            
            adv_keys = []
            adv_count = 0
            for ak in adv_f:
                if adv_count != 0:
                    adv_keys.append(ak[0])
                adv_count += 1
#             print(adv_keys)
#             print("adv_count: {}".format(adv_count))
            
            og_count = 0
            adv_match = 0
            for ok in og_f:
#                 if ok[1] in adv_keys:
#                     for dur in adv_flow_durs:
#                         print(int(ok[8]), dur)
#                         if dur + 100000 > int(ok[8]) and dur - 100000 < int(ok[8]):
#                             adv_match += 1
#                             adv_match_indices.append(og_count)
#                             adv_match_flows.append((ok[1], ok[8]))
                if ok[1] in adv_keys and int(ok[8]) in adv_flow_durs:
                    adv_match += 1
                    adv_match_indices.append(og_count)
                    labels_of_indices_to_remove.append(ok[len(ok) - 1])
                    adv_match_flows.append((ok[1], ok[8]))
                og_count += 1
#             print("new indices to remove: {}".format(adv_match))
            print("current loop adv indices length: {}".format(adv_match))

print("END indices to remove: {}".format(adv_match_indices))
print("Total # of indices to remove: {}".format(len(adv_match_indices)))
print("Labels of indices to remove: {}".format(labels_of_indices_to_remove))
# Out:
# ../NetSploit-files/CIC-Feature-Files/CSV-generate/gtg/Thursday-WH-generate-labeled.csv
# ../NetSploit-files/pcaps/DAGMM/BruteForce/BruteForce_Thursday_modded.pcap_Flow.csv
# ../NetSploit-files/json_files/DAGMM/all_in_one/feature_set_Web_Attack_BruteForce_DAGMM_TO.json
# current loop adv indices length: 2
# ../NetSploit-files/pcaps/DAGMM/XSS/XSS_Thursday_modded.pcap_Flow.csv
# ../NetSploit-files/json_files/DAGMM/all_in_one/feature_set_Web_Attack_XSS_DAGMM_TO.json
# current loop adv indices length: 2
# ../NetSploit-files/pcaps/DAGMM/Infiltration/Infiltration_Thursday_modded.pcap_Flow.csv
# ../NetSploit-files/json_files/DAGMM/all_in_one/feature_set_Infiltration_DAGMM_TO.json
# current loop adv indices length: 6
# END indices to remove: [24827, 24864, 24015, 26125, 437291, 437293, 437305, 437306, 437308, 437316]
# Total # of indices to remove: 10
# ...

# %%
bot_bi_adv_feat[1] == bot_og_feat[1]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
print(bot_og_feat[1])
# Out:
# [8.00000000e+01 1.03967000e+05 1.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.92368732e+01
#  1.03967000e+05 0.00000000e+00 1.03967000e+05 1.03967000e+05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.20000000e+01 3.20000000e+01
#  9.61843662e+00 9.61843662e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
# ...

# %%
x = 5
a = "as"
newFlow = "192.168.10.12-52.51.222.188-43130-80-6"

feature_set = {
    "flows": {}
}

feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"] = {}
feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"]["features"] = {}
feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"]["features"]["Tot Fwd Pkts"] = {}
feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"]["features"]["Tot Fwd Pkts"]["og"] = 5
feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"]["features"]["Tot Fwd Pkts"]["adv"] = 7
# feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"]["features"]["Tot Fwd Pkts"]["og"] = 5


#     "features": {}
# #     "adv": {
# #         "tot": x,
# #         a: []
# #     }
# }

# feature_set["features"]["Tot Fwd Pkts"] = {}
# feature_set["features"]["Tot Fwd Pkts"]["og"] = 5
# feature_set["features"]["Tot Fwd Pkts"]["adv"] = 10
# feature_set["features"]["T"]

# feature_set["adv"][a].append("qwe")
print("features" in feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"])

print(feature_set)
"features" in feature_set["flows"]
print("Tot Fwd Pkts" in feature_set["flows"]["6,192.168.10.12,43130, 52.51.222.188, 80"]["features"])
# Out:
# True
# {'flows': {'6,192.168.10.12,43130, 52.51.222.188, 80': {'features': {'Tot Fwd Pkts': {'og': 5, 'adv': 7}}}}}
# True

# %%
ts = bot_ids[0][6]
ts = ts.split(' ')
print(ts)
date = ts[0].split('/')
time = ts[1].split(':')
dn = ts[2]

import datetime
# timestamp = datetime.datetime(int(date[2]), int(date[1]), int(date[0]), int(time[0]), int(time[1]), int(time[2])).timestamp()

timestamp = datetime.datetime(int(date[2]), int(date[1]), int(date[0]), int(time[0]), int(time[1]), int(time[2]))

print(type(timestamp))
# Out:
# ['07/07/2017', '12:42:09', 'PM']
# <class 'datetime.datetime'>

# %%
def test(index):
    index += 1

i = 4
test(4)
print(i)
# Out:
# 4
